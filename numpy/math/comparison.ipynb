# %% [markdown]
# ## Comparison
# ---

# %%
import numpy as np

a = np.array([5, 7, 8])
b = np.array([5, 44, 8])

# %%
a == b
# Out:
# array([ True, False,  True])

# %%
a < 6
# Out:
# array([ True, False, False])

# %%
np.array_equal(a, b)
# Out:
# False
