# %% [markdown]
# ## Inspecting Array
# ---

# %%
import numpy as np

a = np.zeros((5, 10, 5))
b = np.zeros((5, 5))
c = np.zeros(5)

# %% [markdown]
# ---
# Array dimensions

# %%
a.shape

# %%
b.shape

# %%
c.shape

# %% [markdown]
# ---
# Length of array

# %%
len(a)

# %%
len(b)

# %%
len(c)

# %% [markdown]
# ---
# Number of array dimensions

# %%
a.ndim

# %%
b.ndim

# %%
c.ndim

# %% [markdown]
# ---
# Number of array elements

# %%
a.size

# %%
b.size

# %%
c.size

# %% [markdown]
# ---
# Data type of arry elements

# %%
a.dtype

# %% [markdown]
# ---
# Convert an array to a different type

# %%
a.astype(int)
