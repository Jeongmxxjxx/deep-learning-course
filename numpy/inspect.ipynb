# %% [markdown]
# ## Inspecting Array
# ---

# %%
import numpy as np

a = np.zeros((5, 5, 5))
b = np.zeros((5, 5))
c = np.zeros(5)

# %% [markdown]
# ---
# ## Array dimensions

# %%
a.shape
# Out:
# (5, 5)

# %%
b.shape
# Out:
# (5,)
